# %%
import nltk
# Nếu chưa có thư viện thì download
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\NoName\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\NoName\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
from string import punctuation

# %%
print stopwords.words('english')
# Out:
# [u'i', u'me', u'my', u'myself', u'we', u'our', u'ours', u'ourselves', u'you', u"you're", u"you've", u"you'll", u"you'd", u'your', u'yours', u'yourself', u'yourselves', u'he', u'him', u'his', u'himself', u'she', u"she's", u'her', u'hers', u'herself', u'it', u"it's", u'its', u'itself', u'they', u'them', u'their', u'theirs', u'themselves', u'what', u'which', u'who', u'whom', u'this', u'that', u"that'll", u'these', u'those', u'am', u'is', u'are', u'was', u'were', u'be', u'been', u'being', u'have', u'has', u'had', u'having', u'do', u'does', u'did', u'doing', u'a', u'an', u'the', u'and', u'but', u'if', u'or', u'because', u'as', u'until', u'while', u'of', u'at', u'by', u'for', u'with', u'about', u'against', u'between', u'into', u'through', u'during', u'before', u'after', u'above', u'below', u'to', u'from', u'up', u'down', u'in', u'out', u'on', u'off', u'over', u'under', u'again', u'further', u'then', u'once', u'here', u'there', u'when', u'where', u'why', u'how', u'all', u'any', u'both', u'e
# ...

# %%
print punctuation
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
# Tạo danh sách stop words từ từ điển stop word và các dấu chấm câu
stop_words = set(stopwords.words('english') + list(punctuation))
lemma = WordNetLemmatizer()

# %%
# Văn bản mẫu
str1 = "war duck brid this is a string. Hello my life?"
str2 = "Your best photographs of 2012. GALLERY: http://bbc.in/UvZxmS"
str3 = "The discovery of Higgs, a robot landing on Mars and planet Venus trekking across the sun...This year has been full of significant scientific events and discoveries: http://bbc.in/12K9joaWhat is your most memorable science moment of 2012?"

# %%
# Xoá các kí tự đặc biệt 
def remove_ascii(text):
    return "".join([word for word in text if ord(word) < 128 ])

# %%
# Text method remove_ascii
print remove_ascii(str1)
print remove_ascii(str2)
print remove_ascii(str3)
# Out:
# war duck brid this is a string. Hello my life?
# Your best photographs of 2012. GALLERY: http://bbc.in/UvZxmS
# The discovery of Higgs, a robot landing on Mars and planet Venus trekking across the sun...This year has been full of significant scientific events and discoveries: http://bbc.in/12K9joaWhat is your most memorable science moment of 2012?

# %%
# Text method remove_punctuation
print remove_punctuation(str1)
print remove_punctuation(str2)
print remove_punctuation(str3)
# Out:
# war duck brid this is a string Hello my life
# Your best photographs of 2012 GALLERY httpbbcinUvZxmS
# The discovery of Higgs a robot landing on Mars and planet Venus trekking across the sunThis year has been full of significant scientific events and discoveries httpbbcin12K9joaWhat is your most memorable science moment of 2012

# %%
# Xử lý text
def clean_text(text):
    text_not_punctuation = remove_punctuation(text) #Xoá dấu chấm đi liền 
    text_ascii = remove_ascii(text_not_punctuation ) # Xoá các ký tự không cần thiết
    stop_free = " ".join([word for word in text_ascii.lower().split() if word not in stop_words]) # Xoá các ký tự stop word
    normalized = " ".join(lemma.lemmatize(word,'v') for word in stop_free.split()) #Chuyển về từ gốc
    return [word for word in normalized.split() if len(word) > 2]

# %%
# Text method clean_text
print clean_text(str1)
print clean_text(str2)
print clean_text(str3)
# Out:
# ['war', 'duck', 'brid', 'string', 'hello', 'life']
# [u'best', u'photograph', u'2012', u'gallery', u'httpbbcinuvzxms']
# [u'discovery', u'higgs', u'robot', u'land', u'mar', u'planet', u'venus', u'trek', u'across', u'sunthis', u'year', u'full', u'significant', u'scientific', u'events', u'discoveries', u'httpbbcin12k9joawhat', u'memorable', u'science', u'moment', u'2012']

# %%
from nltk.corpus import brown
nltk.download('brown')
news_text = brown.words(categories='humor')
fdist = nltk.FreqDist(w.lower() for w in news_text)
modals = ['can', 'could', 'may', 'might', 'must', 'will']
for m in modals:
    print(m + ':', fdist[m])
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\NoName\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# ('can:', 17)
# ('could:', 33)
# ('may:', 8)
# ('might:', 8)
# ('must:', 9)
# ('will:', 13)

# %%
print news_text[10:20]
# Out:
# [u'Barco', u'!', u'!', u'For', u'it', u'seems', u'that', u'Barco', u',', u'fancying']
