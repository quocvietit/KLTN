# %%
from pyvi import ViTokenizer
class NLP(object):
    def __init__(self, text = None):
        self.text = text
        self.__set_stopwords()

    def segmentation(self):
        return ViTokenizer.tokenize(self.text)

# %%
temp = u"Chào các bạn tôi là Phạm Văn Toàn đến từ blog Tự học Machine Learning"
print NLP(text=temp).segmentation()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-fa8096165e84> in <module>()
#       1 temp = u"Chào các bạn tôi là Phạm Văn Toàn đến từ blog Tự học Machine Learning"
# ----> 2 print NLP(text=temp).segmentation()
#
# <ipython-input-1-ff471e6a77a0> in __init__(self, text)
#       3     def __init__(self, text = None):
#       4         self.text = text
# ----> 5         self.__set_stopwords()
#       6
#       7     def segmentation(self):
#
# AttributeError: 'NLP' object has no attribute '_NLP__set_stopwords'
