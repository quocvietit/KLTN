# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# %%
documents = ["This little kitty came to play when I was eating at a restaurant.",
             "Merley has the best squooshy kitten belly.",
             "Google Translate app is incredible.",
             "If you open 100 tab in google you get a smiley face.",
             "Best cat photo I've ever taken.",
             "Climbing ninja cat.",
             "Impressed with google map feedback.",
             "Key promoter extension for Google Chrome."]

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(documents)

# %%
true_k = 3
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=3, n_init=1, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print
# Out:
# Top terms per cluster:
# Cluster 0:  climbing  ninja  cat  100  face  tab  smiley  open  google  impressed
# Cluster 1:  best  ve  photo  taken  belly  merley  kitten  squooshy  restaurant  came
# Cluster 2:  google  incredible  app  translate  feedback  impressed  map  key  promoter  chrome

# %%
print("\n")
print("Prediction")

Y = vectorizer.transform(["chrome browser to open."])
prediction = model.predict(Y)
print(prediction)
 
Y = vectorizer.transform([""])
prediction = model.predict(Y)
print(prediction)
# Out:
# Prediction
# [2]
# [1]

# %%
import string
import collections
 
from nltk import word_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from pprint import pprint
 
 
def process_text(text, stem=True):
    """ Tokenize text and stem words removing punctuation """
    text = text.translate(None, string.punctuation)
    tokens = word_tokenize(text)
 
    if stem:
        stemmer = PorterStemmer()
        tokens = [stemmer.stem(t) for t in tokens]
 
    return tokens
 
 
def cluster_texts(texts, clusters=3):
    """ Transform texts to Tf-Idf coordinates and cluster texts using K-Means """
    vectorizer = TfidfVectorizer(tokenizer=process_text,
                                 stop_words=stopwords.words('english'),
                                 max_df=0.5,
                                 min_df=0.1,
                                 lowercase=True)
 
    tfidf_model = vectorizer.fit_transform(texts)
    km_model = KMeans(n_clusters=clusters)
    km_model.fit(tfidf_model)
 
    clustering = collections.defaultdict(list)
 
    for idx, label in enumerate(km_model.labels_):
        clustering[label].append(idx)
 
    return clustering
 
 
if __name__ == "__main__":
    articles = ["this is a google"]
    clusters = cluster_texts(articles, 7)
    pprint(dict(clusters))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-49252d79306d> in <module>()
#      44 if __name__ == "__main__":
#      45     articles = ["this is a google"]
# ---> 46     clusters = cluster_texts(articles, 7)
#      47     pprint(dict(clusters))
#
# <ipython-input-22-49252d79306d> in cluster_texts(texts, clusters)
#      30                                  lowercase=True)
#      31
# ---> 32     tfidf_model = vectorizer.fit_transform(texts)
#      33     km_model = KMeans(n_clusters=clusters)
#      34     km_model.fit(tfidf_model)
#
# V:\Anaconda\lib\site-packages\sklearn\feature_extraction\text.pyc in fit_transform(self, raw_documents, y)
#    1379             Tf-idf-weighted document-term matrix.
#    1380         """
# -> 1381         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1382         self._tfidf.fit(X)
#    1383         # X is already a transformed view of raw_documents so
#
# V:\Anaconda\lib\site-packages\sklearn\feature_extraction\text.pyc in fit_transform(self, raw_documents, y)
#     867
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
#     870
#     871         if self.binary:
#
# V:\Anaconda\lib\site-packages\sklearn\feature_extraction\text.pyc in _count_vocab(self, raw_documents, fixed_vocab)
#     790         for doc in raw_documents:
#     791             feature_counter = {}
# --> 792             for feature in analyze(doc):
#     793                 try:
#     794                     feature_idx = vocabulary[feature]
#
# V:\Anaconda\lib\site-packages\sklearn\feature_extraction\text.pyc in <lambda>(doc)
#     264
#     265             return lambda doc: self._word_ngrams(
# --> 266                 tokenize(preprocess(self.decode(doc))), stop_words)
#     267
#     268         else:
#
# <ipython-input-22-49252d79306d> in process_text(text, stem)
#      12 def process_text(text, stem=True):
#      13     """ Tokenize text and stem words removing punctuation """
# ---> 14     text = text.translate(None, string.punctuation)
#      15     tokens = word_tokenize(text)
#      16
#
# TypeError: translate() takes exactly one argument (2 given)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\NoName\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True
