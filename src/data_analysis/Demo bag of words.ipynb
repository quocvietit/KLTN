# %% [markdown]
# # Demo cluter text

# %%
from pyvi import ViTokenizer, ViPosTagger
from sklearn.base import TransformerMixin, BaseEstimator

# %%
class FeatureTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.tokenizer = ViTokenizer()
        self.pos_tagger = ViPosTagger()

    def fit(self, *_):
        return self

    def transform(self, X, y=None, **fit_params):
        result = X.apply(lambda text: self.tokenizer.tokenize(text))
        return result

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(names['year'], names['M'])
plot(names['year'][::4], names['F'][::4],'-o', alpha=0.5)
show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-62cbd5696877> in <module>()
# ----> 1 plt.plot(names['year'], names['M'])
#       2 plot(names['year'][::4], names['F'][::4],'-o', alpha=0.5)
#       3 show()
#
# NameError: name 'names' is not defined
