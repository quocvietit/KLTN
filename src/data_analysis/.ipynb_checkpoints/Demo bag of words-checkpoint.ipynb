# %% [markdown]
# # Demo cluter text

# %%
import pyvi
from pyvi.pyvi import ViTokenizer, ViPosTagger
from sklearn.base import TransformerMixin, BaseEstimator
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-c754fabd9d0b> in <module>()
#       1 import pyvi
# ----> 2 from pyvi.pyvi import ViTokenizer, ViPosTagger
#       3 from sklearn.base import TransformerMixin, BaseEstimator
#
# ImportError: No module named pyvi

# %%
class FeatureTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.tokenizer = ViTokenizer()
        self.pos_tagger = ViPosTagger()

    def fit(self, *_):
        return self

    def transform(self, X, y=None, **fit_params):
        result = X.apply(lambda text: self.tokenizer.tokenize(text))
        return result
